# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
#getting an understanding of how the data is presented
msft = yf.Ticker('msft')
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software—Infrastructure',
#  'industryDisp': 'Software—Infrastructure',
#  'sector': 'Technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and power automate; and on-premises ERP and CRM applications. The Intelligent Cloud segment provides server products and cloud services, such as azure and other cloud services; SQL and windows server, visual studio, system center, and related client access licenses, as well as nuance and GitHub; and enterprise services including enterprise support services, industry solutions, and nuance professional services. The More Personal Computing segment offers Windows, including windows OEM licensing and other non-volume licensing of the Windows operating system; Windows commercial comprising volume licensing of the Windows operating system, windows cloud services, and other Windows commercial offerings; patent licensing; and windows Internet of Things; and devices, such as surface, HoloLens, and PC accessories. Additionally, this segment provides gaming, which includes Xbox hardware and content, and first- and third-party content; Xbox game pass and other subscriptions, cloud gaming, advertising, third-party disc royalties, and other cloud services; and search and news advertising, which includes Bing, Microsoft News and Edge, and third-party affiliates. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online, and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.',
#  'fullTimeEmployees': 221000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Satya  Nadella',
#    'age': 55,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1967,
#    'fiscalYear': 2022,
#    'totalPay': 12676750,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bradford L. Smith LCA',
#    'age': 63,
#    'title': 'Pres & Vice Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2022,
#    'totalPay': 4655274,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Amy E. Hood',
#    'age': 50,
#    'title': 'Exec. VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2022,
#    'totalPay': 4637915,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Judson  Althoff',
#    'age': 49,
#    'title': 'Exec. VP & Chief Commercial Officer',
#    'yearBorn': 1973,
#    'fiscalYear': 2022,
#    'totalPay': 4428268,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Christopher David Young',
#    'age': 50,
#    'title': 'Exec. VP of Bus. Devel., Strategy & Ventures',
#    'yearBorn': 1972,
#    'fiscalYear': 2022,
#    'totalPay': 4588876,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alice L. Jolla',
#    'age': 55,
#    'title': 'Corp. VP & Chief Accounting Officer',
#    'yearBorn': 1967,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James Kevin Scott',
#    'age': 50,
#    'title': 'Exec. VP of AI & CTO',
#    'yearBorn': 1972,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Brett  Iversen',
#    'title': 'VP of Investor Relations',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hossein  Nowbar',
#    'title': 'Chief Legal Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frank X. Shaw',
#    'title': 'Chief Communications Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 6,
#  'boardRisk': 3,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 2,
#  'overallRisk': 2,
#  'governanceEpochDate': 1693526400,
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 312.14,
#  'open': 312.3,
#  'dayLow': 311.81,
#  'dayHigh': 313.7,
#  'regularMarketPreviousClose': 312.14,
#  'regularMarketOpen': 312.3,
#  'regularMarketDayLow': 311.81,
#  'regularMarketDayHigh': 313.7,
#  'dividendRate': 3.0,
#  'dividendYield': 0.0095999995,
#  'exDividendDate': 1700006400,
#  'payoutRatio': 0.2748,
#  'fiveYearAvgDividendYield': 1.05,
#  'beta': 0.904564,
#  'trailingPE': 32.327477,
#  'forwardPE': 26.23051,
#  'volume': 1780183,
#  'regularMarketVolume': 1780183,
#  'averageVolume': 24820730,
#  'averageVolume10days': 23032380,
#  'averageDailyVolume10Day': 23032380,
#  'bid': 313.09,
#  'ask': 313.28,
#  'bidSize': 1100,
#  'askSize': 1000,
#  'marketCap': 2324994719744,
#  'fiftyTwoWeekLow': 213.43,
#  'fiftyTwoWeekHigh': 366.78,
#  'priceToSalesTrailing12Months': 10.971355,
#  'fiftyDayAverage': 329.7192,
#  'twoHundredDayAverage': 295.1553,
#  'trailingAnnualDividendRate': 2.72,
#  'trailingAnnualDividendYield': 0.008714038,
#  'currency': 'USD',
#  'enterpriseValue': 2287311519744,
#  'profitMargins': 0.34146,
#  'floatShares': 7423448423,
#  'sharesOutstanding': 7429760000,
#  'sharesShort': 41145504,
#  'sharesShortPriorMonth': 31028035,
#  'sharesShortPreviousMonthDate': 1692057600,
#  'dateShortInterest': 1694736000,
#  'sharesPercentSharesOut': 0.0055,
#  'heldPercentInsiders': 0.00052,
#  'heldPercentInstitutions': 0.73212,
#  'shortRatio': 2.04,
#  'shortPercentOfFloat': 0.0055,
#  'impliedSharesOutstanding': 7429760000,
#  'bookValue': 27.748,
#  'priceToBook': 11.27757,
#  'lastFiscalYearEnd': 1688083200,
#  'nextFiscalYearEnd': 1719705600,
#  'mostRecentQuarter': 1688083200,
#  'earningsQuarterlyGrowth': 0.2,
#  'netIncomeToCommon': 72361000960,
#  'trailingEps': 9.68,
#  'forwardEps': 11.93,
#  'pegRatio': 2.22,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1045526400,
#  'enterpriseToRevenue': 10.794,
#  'enterpriseToEbitda': 22.42,
#  '52WeekChange': 0.29481065,
#  'SandP52WeekChange': 0.14909494,
#  'lastDividendValue': 0.68,
#  'lastDividendDate': 1692144000,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'underlyingSymbol': 'MSFT',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'firstTradeDateEpochUtc': 511108200,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': 'b004b3ec-de24-385e-b2c1-923f10d3fb62',
#  'messageBoardId': 'finmb_21835',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 312.93,
#  'targetHighPrice': 415.42,
#  'targetLowPrice': 269.08,
#  'targetMeanPrice': 369.29,
#  'targetMedianPrice': 377.66,
#  'recommendationMean': 1.7,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 42,
#  'totalCash': 111256002560,
#  'totalCashPerShare': 14.974,
#  'ebitda': 102022995968,
#  'totalDebt': 79441002496,
#  'quickRatio': 1.536,
#  'currentRatio': 1.769,
#  'totalRevenue': 211914997760,
#  'debtToEquity': 38.522,
#  'revenuePerShare': 28.46,
#  'returnOnAssets': 0.14245,
#  'returnOnEquity': 0.38824,
#  'freeCashflow': 47268999168,
#  'operatingCashflow': 87581999104,
#  'earningsGrowth': 0.202,
#  'revenueGrowth': 0.083,
#  'grossMargins': 0.6892,
#  'ebitdaMargins': 0.48143002,
#  'operatingMargins': 0.41772997,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.2895}

# %%
msft.info['longBusinessSummary']
# Out:
# 'Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and power automate; and on-premises ERP and CRM applications. The Intelligent Cloud segment provides server products and cloud services, such as azure and other cloud services; SQL and windows server, visual studio, system center, and related client access licenses, as well as nuance and GitHub; and enterprise services including enterprise support services, industry solutions, and nuance professional services. The More Personal Computing segment offers Windows, including windows OEM licensing and other non-volume licensing of the Windows operating system; Windows commercial comprising volume licensing of the Windows operating system, windows cloud services, and other Windows commercial offerings; patent licensing; and windows Internet of Things; and devices, such as surface, HoloLens, and PC accessories. Additionally, this segment provides gaming, which includes Xbox hardware and content, and first- and third-party content; Xbox game pass and other subscriptions, cloud gaming, advertising, third-party disc royalties, and other cloud services; and search and news advertising, which includes Bing, Microsoft News and Edge, and third-party affiliates. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online, and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.'

# %%
#Create a list of tickers
tickers = ['UNH','gs','msft','hd','cat','mcd','amgn','v','crm','ba','hon','aapl','trv','cvx','wmt','jnj','axp','pg','ibm','jpm','mrk','mmm','nke','dis','ko','csco','dow','intc','vz','wba']
tickers
# Out:
# ['UNH',
#  'gs',
#  'msft',
#  'hd',
#  'cat',
#  'mcd',
#  'amgn',
#  'v',
#  'crm',
#  'ba',
#  'hon',
#  'aapl',
#  'trv',
#  'cvx',
#  'wmt',
#  'jnj',
#  'axp',
#  'pg',
#  'ibm',
#  'jpm',
#  'mrk',
#  'mmm',
#  'nke',
#  'dis',
#  'ko',
#  'csco',
#  'dow',
#  'intc',
#  'vz',
#  'wba']

# %%
#Download a years worth of historical data for components of the Dow Jones Industrail Index
data = yf.download(['unh','gs','msft','hd','cat','mcd','amgn','v','crm','ba','hon','aapl','trv','cvx','wmt','jnj','axp','pg','ibm','jpm','mrk','mmm','nke','dis','ko','csco','dow','intc','vz','wba'],start = '2022-09-01',end='2023-09-26',group_by = 'ticker')
data.head()
# Out:
# [*********************100%***********************]  30 of 30 completed
#                    UNH                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 2022-09-01  519.330017  524.260010  515.090027  524.000000  514.782043
# 2022-09-02  529.619995  529.789978  513.809998  516.349976  507.266571
# 2022-09-06  519.929993  527.450012  516.919983  517.679993  508.573181
# 2022-09-07  517.000000  523.500000  514.679993  521.679993  512.502869
# 2022-09-08  520.950012  528.489990  518.809998  527.510010  518.230286
#
#                             TRV                                      ...  \
#              Volume        Open        High         Low       Close  ...
# Date                                                                 ...
# 2022-09-01  2085300  161.220001  164.300003  160.410004  163.300003  ...
# 2022-09-02  1944200  164.820007  166.130005  161.779999  162.699997  ...
# 2022-09-06  2711900  163.720001  164.300003  161.600006  161.880005  ...
# 2022-09-07  2504400  161.770004  164.770004  161.600006  164.020004  ...
# 2022-09-08  1557500  162.649994  165.039993  161.839996  164.509995  ...
#
#                    JNJ                                         MRK             \
#                    Low       Close   Adj Close   Volume       Open       High
# Date
# 2022-09-01  161.479996  165.339996  160.718201  7509600  85.639999  87.459999
# 2022-09-02  162.009995  162.740005  158.190903  5803700  87.239998  87.779999
# 2022-09-06  162.820007  163.179993  158.618576  7394600  86.580002  87.269997
# 2022-09-07  162.160004  164.070007  159.483704  4590600  86.559998  87.000000
# 2022-09-08  163.080002  165.389999  160.766815  5838400  86.500000  87.449997
#
#
#                   Low      Close  Adj Close   Volume
# Date
# 2022-09-01  85.360001  87.150002  84.151283  7528600
# 2022-09-02  85.879997  86.230003  83.262947  6997500
# 2022-09-06  86.160004  86.419998  83.446404  8244300
# 2022-09-07  85.070000  86.870003  83.880920  6121700
# 2022-09-08  86.129997  87.419998  84.411995  8109200
#
# [5 rows x 180 columns]

# %%
#Download a years worth of historical data for components of the Dow Jones Industrail Index
data = yf.download(tickers,start = '2022-09-01',end='2023-09-26',group_by = 'ticker')
data.head()
# Out:
# [*********************100%***********************]  30 of 30 completed
#                    TRV                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 2022-09-01  161.220001  164.300003  160.410004  163.300003  158.816422
# 2022-09-02  164.820007  166.130005  161.779999  162.699997  158.232895
# 2022-09-06  163.720001  164.300003  161.600006  161.880005  157.435425
# 2022-09-07  161.770004  164.770004  161.600006  164.020004  159.516663
# 2022-09-08  162.649994  165.039993  161.839996  164.509995  160.905533
#
#                             CVX                                      ...  \
#              Volume        Open        High         Low       Close  ...
# Date                                                                 ...
# 2022-09-01  1041300  156.479996  156.880005  153.229996  155.539993  ...
# 2022-09-02  1244400  158.240005  159.130005  156.720001  157.850006  ...
# 2022-09-06   963500  159.889999  159.990005  155.710007  157.119995  ...
# 2022-09-07  1569900  154.059998  155.820007  152.619995  155.110001  ...
# 2022-09-08  1404200  155.589996  156.380005  153.380005  155.949997  ...
#
#                   MRK                                        JNJ              \
#                   Low      Close  Adj Close   Volume        Open        High
# Date
# 2022-09-01  85.360001  87.150002  84.151283  7528600  161.490005  165.500000
# 2022-09-02  85.879997  86.230003  83.262955  6997500  165.860001  166.199997
# 2022-09-06  86.160004  86.419998  83.446404  8244300  163.940002  166.220001
# 2022-09-07  85.070000  86.870003  83.880920  6121700  162.910004  164.419998
# 2022-09-08  86.129997  87.419998  84.411995  8109200  163.880005  165.419998
#
#
#                    Low       Close   Adj Close   Volume
# Date
# 2022-09-01  161.479996  165.339996  160.718185  7509600
# 2022-09-02  162.009995  162.740005  158.190887  5803700
# 2022-09-06  162.820007  163.179993  158.618561  7394600
# 2022-09-07  162.160004  164.070007  159.483719  4590600
# 2022-09-08  163.080002  165.389999  160.766800  5838400
#
# [5 rows x 180 columns]

# %%
# Creating a CSV file from the data
data.to_csv("historical_data.csv")

# %%
# Create an empty DataFrame to store the data
additional_data = pd.DataFrame()

# Iterate through each ticker and retrieve information
for ticker in tickers:
    stock = yf.Ticker(ticker)
    info = stock.info
    
    # Extract the relevant information for the current ticker
    fundamentals = {
        'Ticker': ticker,
        'MarketCap': info.get('marketCap', None),
        'FiftyTwoWeekHigh': info.get('fiftyTwoWeekHigh', None),
        'EarningsPerShare': info.get('trailingEps', None),
        'PE_Ratio': info.get('trailingPE', None),
        'DividendYield': info.get('dividendYield', None),
        'GrossProfitMargin': info.get('grossMargins', None),
        'NetIncome': info.get('netIncomeToCommon', None),
        'BookValuePerShare': info.get('bookValue', None),
        'TotalDebt': info.get('totalDebt', None),
        'CurrentRatio': info.get('currentRatio', None),
        'DebtToEquityRatio': info.get('debtToEquity', None),
}
    
    # Append the data for the current ticker to the DataFrame
    additional_data = additional_data.append(fundamentals, ignore_index=True)
    

# Print the resulting DataFrame
print(additional_data.head())
# Out:
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)
#   Ticker      MarketCap  FiftyTwoWeekHigh EarningsPerShare   PE_Ratio  \
# 0    UNH   466311217152            558.10            22.34   22.53402
# 1     gs   106173841408            389.58            23.51  13.698852
# 2   msft  2316962627584            366.78             9.68  32.215794
# 3     hd   303251226624            347.25            16.03  18.916407
# 4    cat   140012371968            293.88             None  20.056213
#
#   DividendYield GrossProfitMargin    NetIncome BookValuePerShare  \
# 0         0.014           0.24792  21108000768            88.838
# 1         0.034           0.83022   8253000192           303.873
# 2        0.0096            0.6892  72361000960            27.748
# 3        0.0276           0.33487  16232999936             1.334
# 4          None              None         None              None
#
#       TotalDebt CurrentRatio DebtToEquityRatio
# 0   65588998144        0.763            71.172
# 1  638347968512        1.642           545.485
# 2   79441002496        1.769            38.522
# 3   49493000192        1.314          3707.341
# 4          None         None              None
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3533703434.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   additional_data = additional_data.append(fundamentals, ignore_index=True)

# %%
#export to a csv file
additional_data.to_csv("fundamental_data.csv")

# %%
description = pd.DataFrame()

# Iterate through each ticker and retrieve information
for ticker in tickers:
    stock = yf.Ticker(ticker)
    info = stock.info
    
    # Extract the relevant information for the current ticker
    profile = {
        'Ticker': ticker,
        'LongBusinessSummary': info.get('longBusinessSummary', None)
    }
    
    # Append the data for the current ticker to the DataFrame
    description = description.append(profile, ignore_index=True)

# Print the resulting DataFrame
print(description)
# Out:
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)
#    Ticker                                LongBusinessSummary
# 0     UNH  UnitedHealth Group Incorporated operates as a ...
# 1      gs  The Goldman Sachs Group, Inc., a financial ins...
# 2    msft  Microsoft Corporation develops and supports so...
# 3      hd  The Home Depot, Inc. operates as a home improv...
# 4     cat                                               None
# 5     mcd  McDonald's Corporation operates and franchises...
# 6    amgn  Amgen Inc. discovers, develops, manufactures, ...
# 7       v  Visa Inc. operates as a payments technology co...
# 8     crm  Salesforce, Inc. provides Customer Relationshi...
# 9      ba  The Boeing Company, together with its subsidia...
# 10    hon  Honeywell International Inc. operates as a div...
# 11   aapl  Apple Inc. designs, manufactures, and markets ...
# 12    trv  The Travelers Companies, Inc., through its sub...
# 13    cvx  Chevron Corporation, through its subsidiaries,...
# 14    wmt  Walmart Inc. engages in the operation of retai...
# 15    jnj  Johnson & Johnson, together with its subsidiar...
# 16    axp  American Express Company, together with its su...
# 17     pg  The Procter & Gamble Company provides branded ...
# 18    ibm  International Business Machines Corporation, t...
# 19    jpm  JPMorgan Chase & Co. operates as a financial s...
# 20    mrk  Merck & Co., Inc. operates as a healthcare com...
# 21    mmm  3M Company provides diversified technology ser...
# 22    nke  NIKE, Inc., together with its subsidiaries, de...
# 23    dis  The Walt Disney Company, together with its sub...
# 24     ko  The Coca-Cola Company, a beverage company, man...
# 25   csco  Cisco Systems, Inc. designs, manufactures, and...
# 26    dow  Dow Inc., through its subsidiaries, engages in...
# 27   intc  Intel Corporation designs, develops, manufactu...
# 28     vz  Verizon Communications Inc., through its subsi...
# 29    wba  Walgreens Boots Alliance, Inc. operates as a p...
# C:\Users\dylan\AppData\Local\Temp\ipykernel_1224\3900406779.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description.append(profile, ignore_index=True)

# %%
description.to_csv("Description.csv")
